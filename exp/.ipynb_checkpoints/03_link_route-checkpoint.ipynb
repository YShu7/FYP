# %% [markdown]
# 1. real dataset
# 1. link the path
#     1. analytical
#     1. statistical
#     - measure the accuracy
#     - marriage matching algorithm
# what you want to maximize

# %% [markdown]
# ### Analytical

# %%
import sqlite3
import pandas as pd
import math
import networkx as nx
import json
import numpy as np
from multiprocessing import Pool
def unpack(row):
    return row['walker_id'], row['time'], float(row['x']), float(row['y'])

# %%
cnx = sqlite3.connect('../corona-sniffer/backend/data/database_3000.db')

df_walks = pd.read_sql_query("SELECT * FROM walks", cnx)
df_walkers = pd.read_sql_query("SELECT * FROM walkers", cnx)
df_v = pd.read_sql_query("SELECT * FROM velocitys", cnx)

# %%
ids = df_v['walker_id'].tolist()

# %%
df_v.head()
# Out:
#     walker_id time                                             x_json  \
# 0  774f6377b5    0  {"mean":11.878909087200725,"dev":3,"v":15.9110...
# 1  fa3cd5a96f    2  {"mean":14.589745907757557,"dev":3,"v":14.2403...
# 2  b8fb2f2cdb    5  {"mean":16.799026624679943,"dev":3,"v":18.7525...
# 3  8e2ad4c380    6  {"mean":18.75254138338596,"dev":3,"v":16.60640...
# 4  8e2ad4c380    7  {"mean":16.606406428772626,"dev":3,"v":13.3611...
#
#                                               y_json  ratio
# 0  {"mean":30.86683282944279,"dev":3,"v":31.75124...   0.97
# 1  {"mean":29.005541277848653,"dev":3,"v":30.8072...   0.97
# 2  {"mean":29.480759844067144,"dev":3,"v":33.9879...   0.97
# 3  {"mean":33.98795510979555,"dev":3,"v":31.65725...   0.97
# 4  {"mean":31.657252568144827,"dev":3,"v":28.1651...   0.97

# %%
def get_probability(x, mean, sd):
    x = x
    var = float(sd)**2
    denom = (2*math.pi*var)**.5
    num = math.exp(-(float(x)-float(mean))**2/(2*var))
    return num/denom

# %%
def find(row):
    walker_id, time, x, y = row

    v_row = df_v.loc[(df_v['walker_id'] == walker_id) & (df_v['time'] == time)].iloc[0]

    x_json, y_json, ratio = json.loads(v_row['x_json']), json.loads(v_row['y_json']), v_row['ratio']

    vx = (x - x_prev) / 10 / ratio
    vy = (y - y_prev) / 10 / ratio
    p = get_probability(vx, x_json['mean'], x_json['dev']) * get_probability(vy, y_json['mean'], y_json['dev'])

    return (p, walker_id)

# %%
matching = {}
i = -1

while True:
    i += 1
    prev = df_walks.loc[df_walks['time'] == str(i)]
    curr = df_walks.loc[df_walks['time'] == str(i+1)]
    if prev.shape[0] == 0:
        break
    for _, row_prev in prev.iterrows():
        walker_id_prev, time_prev, x_prev, y_prev = unpack(row_prev)
        
        rows = []
        for _, row in curr.iterrows():
            walker_id, time, x, y = unpack(row)
            rows.append([walker_id, time, x, y])

        pool = Pool(processes=10)
        max_p, next_id = 0, None
        results = pool.imap_unordered(find, rows)
        pool.close()
        
        for p, walker_id in results:
#             print(p, walker_id)
            if p > max_p:
                max_p, next_id = p, walker_id
#         for _, row in curr.iterrows():
#             walker_id, time, x, y = unpack(row)

#             v_row = df_v.loc[(df_v['walker_id'] == walker_id) & (df_v['time'] == time)].iloc[0]
            
#             x_json, y_json, ratio = json.loads(v_row['x_json']), json.loads(v_row['y_json']), v_row['ratio']

#             vx = (x - x_prev) / 10 / ratio
#             vy = (y - y_prev) / 10 / ratio
#             p = get_probability(vx, x_json['mean'], x_json['dev']) * get_probability(vy, y_json['mean'], y_json['dev'])
            
#             if p > max_p:
#                 max_p, next_id = p, walker_id

        matching[walker_id_prev] = next_id

# %%
graph = nx.Graph([(i, j) for i, j in matching.items() if i and j])
connected_components = sorted(nx.connected_components(graph), key=len, reverse=True)

# %%
real_ids = df_walkers["real_id"].tolist()
id_match = {real_id: set() for real_id in real_ids}
for real_id in real_ids:
    [id_match[real_id].add(id) for id in df_walkers.loc[df_walkers["real_id"] == real_id]['id'].tolist()]

# %%
df_walks_connected = pd.DataFrame(df_walks)
for i, component in enumerate(connected_components):
    new_id = i
    for c in component:
        df_walks_connected = df_walks_connected.replace(c, new_id)

# %%
cnx.execute('DROP TABLE IF EXISTS walks_attached')
df_walks_connected.to_sql('walks_attached', con=cnx)

# %% [markdown]
# ### Statistical

# %%
cnx = sqlite3.connect('../corona-sniffer/backend/data/database_30000.db')

df_walks = pd.read_sql_query("SELECT * FROM walks JOIN walkers ON walkers.id = walks.walker_id", cnx)
df_walkers = pd.read_sql_query("SELECT * FROM walkers", cnx)
df_v = pd.read_sql_query("SELECT * FROM velocitys", cnx)

# %%
df_walks.head()
# Out:
#     walker_id time                 x                 y  \
# 0  6c941deb58    0  361.274388646454  93.7774943499492
# 1  6c941deb58    1  671.463623372485  179.370863352698
# 2  6c4f36901d    5  1805.66148473744  550.615488790935
# 3  4fcb6a8f8d    3  1249.32907878941  355.013187814622
# 4  e56fa980de    7   2447.0202419566  738.863496964905
#
#                                                 json          id  real_id  \
# 0  {"resolved":false,"location":{"latitude":60.16...  6c941deb58        0
# 1  {"resolved":false,"location":{"latitude":60.16...  6c941deb58        0
# 2  {"resolved":false,"location":{"latitude":60.16...  6c4f36901d        0
# 3  {"resolved":false,"location":{"latitude":60.16...  4fcb6a8f8d        0
# 4  {"resolved":false,"location":{"latitude":60.16...  e56fa980de        0
#
#    resolved
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
ids = df_v['walker_id'].tolist()
real_ids = set(df_walks['real_id'].tolist())

# %%
n_total_x, n_total_y = 0, 0
v_dic_x = {}
v_dic_y = {}
for real_id in real_ids:
    walk = df_walks.loc[df_walks['real_id'] == real_id]

    for time in range(walk.shape[0]-1):
        prev = walk.loc[walk['time'] == str(time)]
        curr = walk.loc[walk['time'] == str(time + 1)]
        
        vx = round(float(curr['x']) - float(prev['x']), 0)
        vy = round(float(curr['y']) - float(prev['y']), 0)

        if vx in v_dic_x:
            v_dic_x[vx] += 1
        else:
            v_dic_x[vx] = 1
        n_total_x += 1
        
        if vy in v_dic_y:
            v_dic_y[vy] += 1
        else:
            v_dic_y[vy] = 1
        n_total_y += 1

# %%
for k, v in v_dic_x.items():
    v_dic_x[k] = (v + 1) / (n_total_x + len(v_dic_x.keys()))
for k, v in v_dic_y.items():
    v_dic_y[k] = (v + 1) / (n_total_y + len(v_dic_y.keys()))

# %%
print((n_total_x + len(v_dic_x.keys())), (n_total_y + len(v_dic_y.keys())))
# Out:
# 30770 30818

# %%
cnx = sqlite3.connect('../corona-sniffer/backend/data/database_3000.db')

df_walks = pd.read_sql_query("SELECT * FROM walks", cnx)
df_walkers = pd.read_sql_query("SELECT * FROM walkers", cnx)
df_v = pd.read_sql_query("SELECT * FROM velocitys", cnx)

# %%
def find(row):
    walker_id, time, x, y = row

    v_row = df_v.loc[(df_v['walker_id'] == walker_id) & (df_v['time'] == time)].iloc[0]

    x_json, y_json, ratio = json.loads(v_row['x_json']), json.loads(v_row['y_json']), v_row['ratio']

    vx = round(x - x_prev, 0)
    vy = round(y - y_prev, 0)
    if vx in v_dic_x:
        px = v_dic_x[v]
    else:
        px = 1 / (n_total_x + len(v_dic_x.keys()))
    if vy in v_dic_y:
        py = v_dic_y[v]
    else:
        py = 1 / (n_total_y + len(v_dic_y.keys()))
    return (px * py, walker_id)

#         dis = float('inf')
#         key = None
#         for k, val in v_dic.items():
#             new_dis = ((k[0] - v[0]) ** 2 + (k[1] - v[1]) ** 2)
#             if dis > new_dis:
#                 dis = new_dis
#                 key = k
#         p = v_dic[key]

# %%
matching = {}
for i in range(20):
    prev = df_walks.loc[df_walks['time'] == str(i)]
    curr = df_walks.loc[df_walks['time'] == str(i+1)]
    
    for _, row_prev in prev.iterrows():
        walker_id_prev, time_prev, x_prev, y_prev = unpack(row_prev)
        visited = set()
        
        rows = []
        for _, row in curr.iterrows():
            walker_id, time, x, y = unpack(row)
            rows.append([walker_id, time, x, y])

        pool = Pool(processes=10)
        max_p, next_id = 0, None
        results = pool.imap_unordered(find, rows)
        pool.close()
        
        
        for p, walker_id in results:
#             print(p, walker_id)
            if p > max_p:
                max_p, next_id = p, walker_id
        if walker_id_prev == walker_id:
            continue
        if walker_id not in visited:
            visited.add(walker_id)
            
        
#         max_p, next_id = 0, None
        
#         for _, row in curr.iterrows():
#             walker_id, time, x, y = unpack(row)

#             v_row = df_v.loc[(df_v['walker_id'] == walker_id) & (df_v['time'] == time)].iloc[0]
            
#             x_json, y_json, ratio = json.loads(v_row['x_json']), json.loads(v_row['y_json']), v_row['ratio']

#             v = (x - x_prev, y - y_prev)
#             if v in v_dic:
#                 p = v_dic[v]
#             else:
#                 dis = float('inf')
#                 key = None
#                 for k, val in v_dic.items():
#                     new_dis = ((k[0] - v[0]) ** 2 + (k[1] - v[1]) ** 2)
#                     if dis > new_dis:
#                         dis = new_dis
#                         key = k
#                 p = v_dic[key]
            
#             if p > max_p:
#                 max_p, next_id = p, walker_id

        matching[walker_id_prev] = next_id

# %%
graph = nx.Graph([(i, j) for i, j in matching.items() if i and j])
connected_components = sorted(nx.connected_components(graph), key=len, reverse=True)

# %%
real_ids = df_walkers["real_id"].tolist()
id_match = {real_id: set() for real_id in real_ids}
for real_id in real_ids:
    [id_match[real_id].add(id) for id in df_walkers.loc[df_walkers["real_id"] == real_id]['id'].tolist()]

# %%
df_walks_connected = pd.DataFrame(df_walks)
for i, component in enumerate(connected_components):
    new_id = i
    for c in component:
        df_walks_connected = df_walks_connected.replace(c, new_id)

# %%
cnx.execute('DROP TABLE IF EXISTS walks_attached')
df_walks_connected.to_sql('walks_attached', con=cnx)

# %%
df_walks_connected.loc[df_walks_connected['walker_id'] == 1]
# Out:
#      walker_id time                  x                  y  \
# 494          1    0   356.897459555523   674.652300107164
# 495          1    1   -2.8868522796198    324.69701117171
# 496          1    2  -356.412110984156   5.91812037896756
# 497          1    3  -719.625778812282  -306.243348721563
# 498          1    4  -1050.52103104182  -596.231091885026
# 499          1    5  -1355.38402512899  -890.367612218169
# 500          1    6  -1581.81350084607  -1170.14484100929
# 501          1    7  -1819.13405107576  -1465.11405414636
# 502          1    8  -2086.66013350026  -1787.34692861768
# 503          1    9    -2343.400592895  -2120.32672883463
# 504          1   10  -2584.56766911641  -2440.35364111122
# 505          1   11  -2826.45455878686  -2746.59591124711
# 506          1   12  -3064.48490247568  -3079.49837004353
# 507          1   13  -3267.94595980769  -3423.58725832549
# 508          1   14  -3506.85510152691  -3801.54265225787
# 509          1   15  -3725.91012324616  -4161.20748616977
# 510          1   16  -3949.05807971098  -4517.90396780966
# 511          1   17  -4110.67153197898  -4906.28323449075
# 512          1   18  -4267.14666201105  -5285.72554996701
# 513          1   19  -4420.87869792875  -5670.84139384635
# 514          1   20  -4571.66297947454  -6040.98824858658
# 515          1   21  -4704.09401062698  -6380.44277936355
# 796          1    2   1817.64743307857    243.81198877927
# 797          1    3   2442.07946018114   13.9835820004091
# 1194         1    0  -52.6656363607138   1218.21613986029
# 1195         1    1  -330.414559589799   922.505982201887
# 1196         1    2  -594.871951576484   615.278088069778
# 1197         1    3  -830.951858210622   258.555392881093
# 1198         1    4  -1045.79122006648  -148.312595063411
# 1199         1    5  -1320.65573478023  -553.902250322435
# 1200         1    6  -1557.16403423515  -949.363730157832
# 1201         1    7  -1776.88186304915  -1305.29235294717
# 1202         1    8  -2011.72315249229  -1624.89892245337
# 1203         1    9  -2297.93176739934  -1968.84114817379
# 1204         1   10  -2602.81794728747  -2317.07086903426
# 1205         1   11  -2868.58008013308  -2647.74958719564
# 1594         1    0   273.521138867894   742.530979860337
# 1595         1    1   448.594345481786   184.310469270444
# 1694         1    0  -857.247424734273  -1234.36182838588
# 1695         1    1  -1059.24503359058  -1343.44392883976
# 1696         1    2  -1248.55802382478  -1429.88063305401
# 1697         1    3   -1385.7292249294  -1508.27258372628
# 1698         1    4  -1517.34609368413  -1518.08396063511
# 1699         1    5  -1628.89950493251  -1586.61455283074
# 1700         1    6  -1764.96432377177  -1610.75748665389
# 1701         1    7  -1900.37161552083  -1653.28283855725
# 2797         1    0  -232.046001546436   742.852359258663
# 2798         1    1  -281.650587257093   690.926921600682
#
#                                                    json
# 494   {"resolved":false,"location":{"latitude":60.16...
# 495   {"resolved":false,"location":{"latitude":60.16...
# 496   {"resolved":false,"location":{"latitude":60.16...
# 497   {"resolved":false,"location":{"latitude":60.16...
# 498   {"resolved":false,"location":{"latitude":60.15...
# 499   {"resolved":false,"location":{"latitude":60.15...
# 500   {"resolved":false,"location":{"latitude":60.15...
# 501   {"resolved":false,"location":{"latitude":60.14...
# 502   {"resolved":false,"location":{"latitude":60.14...
# 503   {"resolved":false,"location":{"latitude":60.14...
# 504   {"resolved":false,"location":{"latitude":60.14...
# 505   {"resolved":false,"location":{"latitude":60.13...
# 506   {"resolved":false,"location":{"latitude":60.13...
# 507   {"resolved":false,"location":{"latitude":60.13...
# 508   {"resolved":false,"location":{"latitude":60.12...
# 509   {"resolved":false,"location":{"latitude":60.12...
# 510   {"resolved":false,"location":{"latitude":60.12...
# 511   {"resolved":false,"location":{"latitude":60.11...
# 512   {"resolved":false,"location":{"latitude":60.11...
# 513   {"resolved":false,"location":{"latitude":60.11...
# 514   {"resolved":false,"location":{"latitude":60.10...
# 515   {"resolved":false,"location":{"latitude":60.10...
# 796   {"resolved":true,"location":{"latitude":60.165...
# 797   {"resolved":true,"location":{"latitude":60.163...
# 1194  {"resolved":false,"location":{"latitude":60.17...
# 1195  {"resolved":false,"location":{"latitude":60.17...
# 1196  {"resolved":false,"location":{"latitude":60.16...
# 1197  {"resolved":false,"location":{"latitude":60.16...
# 1198  {"resolved":false,"location":{"latitude":60.16...
# 1199  {"resolved":false,"location":{"latitude":60.15...
# 1200  {"resolved":false,"location":{"latitude":60.15...
# 1201  {"resolved":false,"location":{"latitude":60.15...
# 1202  {"resolved":false,"location":{"latitude":60.14...
# 1203  {"resolved":false,"location":{"latitude":60.14...
# 1204  {"resolved":false,"location":{"latitude":60.14...
# 1205  {"resolved":false,"location":{"latitude":60.13...
# 1594  {"resolved":false,"location":{"latitude":60.16...
# 1595  {"resolved":false,"location":{"latitude":60.16...
# 1694  {"resolved":false,"location":{"latitude":60.15...
# 1695  {"resolved":false,"location":{"latitude":60.15...
# 1696  {"resolved":false,"location":{"latitude":60.15...
# 1697  {"resolved":false,"location":{"latitude":60.14...
# 1698  {"resolved":false,"location":{"latitude":60.14...
# 1699  {"resolved":false,"location":{"latitude":60.14...
# 1700  {"resolved":false,"location":{"latitude":60.14...
# 1701  {"resolved":false,"location":{"latitude":60.14...
# 2797  {"resolved":true,"location":{"latitude":60.169...
# 2798  {"resolved":true,"location":{"latitude":60.169...
